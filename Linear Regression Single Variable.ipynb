# %% [markdown]
# # Machine Learning With Python: Linear Regression With One Variable
# Sample problem of predicting home price in monroe, new jersey (USA)
# Below table represents current home prices in monroe township based on square feet area, new jersey

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# Problem Statement: Given above data build a machine learning model that can predict home prices based on square feet area

# %%
#importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#reading the csv file which has the area and pricing

df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#Plotting the input values

# %matplotlib inline
plt.xlabel('Area(Sq.Ft)')
plt.ylabel('Price(US$)')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
#Creating two data frames with  x axis and y axis

new_df = df.drop('price',axis ='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel('Area(Sq.Ft)',fontsize='20')
plt.ylabel('Price(US $)',fontsize='20')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
#validating with the y=mx+c equation

3300*135.78767123 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict([[5000]])
# Out:
# array([859554.79452055])

# %%
#reading a new csv input files for prediction

d = pd.read_csv("areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   1345
# 3   2467
# 4   2980
# 5   3128
# 6   3756
# 7   4321
# 8   4490
# 9   4789
# 10  5890

# %%
reg.predict(d)
# Out:
# array([316404.10958904, 384297.94520548, 363250.85616438, 515604.62328767,
#        585263.69863014, 605360.2739726 , 690634.93150685, 767354.96575342,
#        790303.08219178, 830903.59589041, 980405.82191781])

# %%
p = reg.predict(d)
p
# Out:
# array([316404.10958904, 384297.94520548, 363250.85616438, 515604.62328767,
#        585263.69863014, 605360.2739726 , 690634.93150685, 767354.96575342,
#        790303.08219178, 830903.59589041, 980405.82191781])

# %%
d['prices'] = p

# %%
d
# Out:
#     area         prices
# 0   1000  316404.109589
# 1   1500  384297.945205
# 2   1345  363250.856164
# 3   2467  515604.623288
# 4   2980  585263.698630
# 5   3128  605360.273973
# 6   3756  690634.931507
# 7   4321  767354.965753
# 8   4490  790303.082192
# 9   4789  830903.595890
# 10  5890  980405.821918

# %%
#writing the predictions to the csv file

d.to_csv("predictions.csv",index = False)
